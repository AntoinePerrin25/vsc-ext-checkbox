# %%
import os

checkbox1 = 0 # [CB]:1|0
if checkbox1:
    file = "exam.txt"
else :
    file = "example.txt"

print(f"File: {file}")

file = "exam.txt" # [CB]: "exam.txt"|"example.txt"

print(f"File: {file}")
